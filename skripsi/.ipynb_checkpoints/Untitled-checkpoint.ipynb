# %%
# !pip install nltk
# !pip install pandas
# !pip install matplotlib
# Out:
# Requirement already satisfied: nltk in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (3.7)
# Requirement already satisfied: click in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: tqdm in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from nltk) (4.62.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from nltk) (2022.1.18)
# Requirement already satisfied: colorama in c:\users\ifarm\appdata\roaming\python\python39\site-packages (from click->nltk) (0.4.4)
# Requirement already satisfied: pandas in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (1.4.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from pandas) (1.22.2)
# Requirement already satisfied: six>=1.5 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (3.5.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.22.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (4.29.1)
# Requirement already satisfied: six>=1.5 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import pandas as pd
import string 
import re #regex library


# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist
from nltk.corpus import stopwords

# %%
#sentence = "dari gambar tersebut saya melihat kemacetan lalu lintas yang sangat parah, kemacetan terjadi karena banyaknya kendaraan roda dua dan roda empat. selain itu, sebab utama dari kemacetan lalu lintas adalah tingginya tingkat kepadatan penduduk."

def load_data():
    data = pd.read_csv('tes1.csv', delimiter =';',encoding= 'unicode_escape') #Memanggil data dari file cvs
    return data

jawaban_df = load_data()
jawaban_df.head(n=10)
# gunakan fungsi .lower()
#lowercase_sentence = sentence.lower()

#print(lowercase_sentence)
# Out:
#            Timestamp                    NAMA :   KELAS :  ABSEN :  \
# 0   1/5/2022 9:54:14   SELVY PUSPITA ANGGRAENI  XI IPS 2       25
# 1   1/5/2022 9:56:40   Nur Riska Yogi Maulani   XI IPS 2       22
# 2   1/5/2022 9:57:48       Citra Wahyu Nurmala  XI IPS 2        5
# 3   1/5/2022 9:58:57            Azwin Faradina  XI IPS 2        3
# 4   1/5/2022 9:58:58            NILA MAHMUDAH   XI IPS 2       18
# 5  1/5/2022 10:00:26  NAURAH VERLITA SALSABILA  XI IPS 2       16
# 6  1/5/2022 10:01:10        CHINTYA NUR LAILIA  XI IPS 2        4
# 7  1/5/2022 10:01:19      Nia Istnaini Firdaus  XI IPS 2       17
# 8  1/5/2022 10:01:25                Malia wati  XI IPS 2       13
# 9  1/5/2022 10:01:34             ELSA NADILIYA  XI IPS 2        8
#
#   Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !
# 0  dari gambar tersebut saya melihat kemacetan la...
# 1      Dapat kita lihat dari keadaan diatas yaitu...
# 2  Pada gambar diatas terjadi kemacetan dikarenak...
# 3  Kemacetan adalah situasi atau keadaan tersenda...
# 4  terlihat kemacetan lalu lintas yang sangat pad...
# 5  terlihat terjadi kemacetan lalu lintas yang sa...
# 6  Kondisi tersebut adalah kepadatan lalu lintas ...
# 7  Gambar di atas merupakan salah satu bentuk dam...
# 8  Peristiwa di atas di sebabkan karena adanya ja...
# 9  dari gambar di atas bisa di simpulkan bahwa ke...

# %%
df = pd.DataFrame(jawaban_df[['NAMA :', 'Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !']])

# %%
df
# Out:
#                      NAMA :  \
# 0   SELVY PUSPITA ANGGRAENI
# 1   Nur Riska Yogi Maulani
# 2       Citra Wahyu Nurmala
# 3            Azwin Faradina
# 4            NILA MAHMUDAH
# 5  NAURAH VERLITA SALSABILA
# 6        CHINTYA NUR LAILIA
# 7      Nia Istnaini Firdaus
# 8                Malia wati
# 9             ELSA NADILIYA
#
#   Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !
# 0  dari gambar tersebut saya melihat kemacetan la...
# 1      Dapat kita lihat dari keadaan diatas yaitu...
# 2  Pada gambar diatas terjadi kemacetan dikarenak...
# 3  Kemacetan adalah situasi atau keadaan tersenda...
# 4  terlihat kemacetan lalu lintas yang sangat pad...
# 5  terlihat terjadi kemacetan lalu lintas yang sa...
# 6  Kondisi tersebut adalah kepadatan lalu lintas ...
# 7  Gambar di atas merupakan salah satu bentuk dam...
# 8  Peristiwa di atas di sebabkan karena adanya ja...
# 9  dari gambar di atas bisa di simpulkan bahwa ke...

# %%
# ------ Case Folding --------
# gunakan fungsi Series.str.lower() pada Pandas
df['NAMA :'] = df['NAMA :'].str.lower()
df['Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !'] = df['Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !'].str.lower()


df.head(n=10)
# Out:
#                      NAMA :  \
# 0   selvy puspita anggraeni
# 1   nur riska yogi maulani
# 2       citra wahyu nurmala
# 3            azwin faradina
# 4            nila mahmudah
# 5  naurah verlita salsabila
# 6        chintya nur lailia
# 7      nia istnaini firdaus
# 8                malia wati
# 9             elsa nadiliya
#
#   Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !
# 0  dari gambar tersebut saya melihat kemacetan la...
# 1      dapat kita lihat dari keadaan diatas yaitu...
# 2  pada gambar diatas terjadi kemacetan dikarenak...
# 3  kemacetan adalah situasi atau keadaan tersenda...
# 4  terlihat kemacetan lalu lintas yang sangat pad...
# 5  terlihat terjadi kemacetan lalu lintas yang sa...
# 6  kondisi tersebut adalah kepadatan lalu lintas ...
# 7  gambar di atas merupakan salah satu bentuk dam...
# 8  peristiwa di atas di sebabkan karena adanya ja...
# 9  dari gambar di atas bisa di simpulkan bahwa ke...

# %%
# df["NAMA :"] = df["NAMA :"].str.lower()
# df["Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !"] = df["Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !"].str.lower()
# df.head(n=10)

# %%
def remove_tweet_special(text):
    # remove tab, new line, ans back slice
    return text.replace('\\t'," ").replace('\\u'," ").replace('\\',"")
               
df['Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !'] = df['Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !'].apply(remove_tweet_special)

#remove number
def remove_number(text):
    return  re.sub(r"\d+", "", str(text))

df['Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !'] = df['Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !'].apply(remove_number)

#remove punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

df['Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !'] = df['Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !'].apply(remove_punctuation)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

df['Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !'] = df['Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ', str(text))

df['Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !'] = df['Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !'].apply(remove_whitespace_multiple)

# remove single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", str(text))

df['Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !'] = df['Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !'].apply(remove_singl_char)

# NLTK word rokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

df['hasil_tokens'] = df['Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(df['hasil_tokens'].head(10))
print('\n\n\n')
# Out:
# Tokenizing Result :
#
# 0    [dari, gambar, tersebut, saya, melihat, kemace...
# 1    [dapat, kita, lihat, dari, keadaan, diatas, ya...
# 2    [pada, gambar, diatas, terjadi, kemacetan, dik...
# 3    [kemacetan, adalah, situasi, atau, keadaan, te...
# 4    [terlihat, kemacetan, lalu, lintas, yang, sang...
# 5    [terlihat, terjadi, kemacetan, lalu, lintas, y...
# 6    [kondisi, tersebut, adalah, kepadatan, lalu, l...
# 7    [gambar, di, atas, merupakan, salah, satu, ben...
# 8    [peristiwa, di, atas, di, sebabkan, karena, ad...
# 9    [dari, gambar, di, atas, bisa, di, simpulkan, ...
# Name: hasil_tokens, dtype: object

# %%
# # import StemmerFactory class
# from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# # create stemmer
# factory = StemmerFactory()
# stemmer = factory.create_stemmer()

# #remove stopword pada list token
# def stemming(text):
#     output   = stemmer.stem(text)
#     return output
# df['Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !'] = df['Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !'].apply(stemming) 

# print(df['Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !'].head(10))
# # stemming process
# # sentence = 'disebuah'
# # output   = stemmer.stem(sentence)

# # print(output)

# !pip install swifter

# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['hasil_tokens']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
# print(len(term_dict))
# print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
#     print(term,":" ,term_dict[term])
    
# print(term_dict)
# print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df['hasil_tokens'] = df['hasil_tokens'].swifter.apply(get_stemmed_term)
print(df['hasil_tokens'].head(n=10))
# Out:
# Requirement already satisfied: swifter in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (1.1.2)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from swifter) (1.4.1)
# Requirement already satisfied: psutil>=5.6.6 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from swifter) (5.9.0)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from swifter) (2022.2.1)
# Requirement already satisfied: tqdm>=4.33.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from swifter) (4.62.3)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from swifter) (7.6.5)
# Requirement already satisfied: cloudpickle>=0.2.2 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from swifter) (2.0.0)
# Requirement already satisfied: parso>0.4.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from swifter) (0.8.3)
# Requirement already satisfied: bleach>=3.1.1 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from swifter) (4.1.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from bleach>=3.1.1->swifter) (1.16.0)
# Requirement already satisfied: packaging in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from bleach>=3.1.1->swifter) (21.3)
# Requirement already satisfied: webencodings in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (6.0)
# Requirement already satisfied: partd>=0.3.10 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (1.2.0)
# Requirement already satisfied: fsspec>=0.6.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (2022.2.0)
# Requirement already satisfied: toolz>=0.8.2 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (0.11.2)
# Requirement already satisfied: numpy>=1.18 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (1.22.2)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets>=7.0.0->swifter) (8.0.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets>=7.0.0->swifter) (6.9.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets>=7.0.0->swifter) (3.5.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets>=7.0.0->swifter) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets>=7.0.0->swifter) (1.0.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from pandas>=1.0.0->swifter) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: colorama in c:\users\ifarm\appdata\roaming\python\python39\site-packages (from tqdm>=4.33.0->swifter) (0.4.4)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (1.5.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (7.1.2)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (0.1.3)
# Requirement already satisfied: nest-asyncio in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (1.5.4)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.1)
# Requirement already satisfied: pickleshare in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (3.0.28)
# Requirement already satisfied: jedi>=0.16 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.18.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (49.2.1)
# Requirement already satisfied: pygments in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.11.2)
# Requirement already satisfied: stack-data in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: backcall in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: decorator in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: black in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (22.1.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (4.4.0)
# Requirement already satisfied: jupyter-core in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (4.9.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from packaging->bleach>=3.1.1->swifter) (3.0.7)
# Requirement already satisfied: locket in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from partd>=0.3.10->dask[dataframe]>=2.10.0->swifter) (0.2.1)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (6.4.8)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (0.18.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (22.3.0)
# Requirement already satisfied: entrypoints in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (0.4)
# Requirement already satisfied: pywin32>=1.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (303)
# Requirement already satisfied: prometheus-client in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.13.1)
# Requirement already satisfied: jinja2 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (3.0.3)
# Requirement already satisfied: argon2-cffi in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.13.1)
# Requirement already satisfied: nbconvert in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (6.4.2)
# Requirement already satisfied: wcwidth in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.5)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from black->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.1.1)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from black->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.0.1)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from black->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from black->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.4.3)
# Requirement already satisfied: click>=8.0.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from black->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (8.0.4)
# Requirement already satisfied: platformdirs>=2 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from black->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.5.1)
# Requirement already satisfied: executing in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.8.2)
# Requirement already satisfied: asttokens in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.2)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (2.1.0)
# Requirement already satisfied: testpath in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (1.5.0)
# Requirement already satisfied: defusedxml in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.5.11)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.8.4)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (2.21)
# Pandas Apply:   0%|          | 0/10 [00:00<?, ?it/s]
# 0    [dari, gambar, sebut, saya, lihat, macet, lalu...
# 1    [dapat, kita, lihat, dari, ada, atas, yaitu, s...
# 2    [pada, gambar, atas, jadi, macet, karena, bany...
# 3    [macet, adalah, situasi, atau, ada, sendat, at...
# 4    [lihat, macet, lalu, lintas, yang, sangat, pad...
# 5    [lihat, jadi, macet, lalu, lintas, yang, sanga...
# 6    [kondisi, sebut, adalah, padat, lalu, lintas, ...
# 7    [gambar, di, atas, rupa, salah, satu, bentuk, ...
# 8    [peristiwa, di, atas, di, sebab, karena, ada, ...
# 9    [dari, gambar, di, atas, bisa, di, simpul, bah...
# Name: hasil_tokens, dtype: object

# %%
# ----------------------- get stopword from NLTK stopword -------------------------------
# get stopword indonesia
list_stopwords = stopwords.words('indonesian')


# ---------------------------- manualy add stopword  ------------------------------------
# append additional stopword
# list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
#                        'kalo', 'amp', 'biar', 'bikin', 'bilang', 
#                        'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
#                        'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
#                        'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
#                        'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
#                        '&amp', 'yah'])

# convert list to dictionary
list_stopwords = set(list_stopwords)

#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

df['hasil_tokens'] = df['hasil_tokens'].apply(stopwords_removal) 


print(df['hasil_tokens'].head(10))
# Out:
# 0    [gambar, lihat, macet, lintas, parah, macet, k...
# 1    [lihat, kendara, jalan, raya, tumpuk, kondusif...
# 2    [gambar, macet, kendara, roda, tingi, padat, d...
# 3    [macet, situasi, sendat, henti, lintas, macet,...
# 4    [lihat, macet, lintas, padat, macet, karna, ke...
# 5    [lihat, macet, lintas, parah, buah, kota, mace...
# 6    [kondisi, padat, lintas, duduk, indonesia, lah...
# 7    [gambar, rupa, salah, bentuk, dampak, tumbuh, ...
# 8    [peristiwa, jalan, jalur, batas, jalan, batas,...
# 9    [gambar, simpul, padat, duduk, macet, macet, h...
# Name: hasil_tokens, dtype: object

# %%
# import string 
# #remove punctuation
# def remove_punctuation(text):
#     return text.translate(str.maketrans("","",string.punctuation))

# df['Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !'] = df['Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !'].apply(remove_punctuation)
# df.head(n=10)

# %%
# #remove whitespace leading & trailing
# def remove_whitespace_LT(text):
#     return text.strip()

# df['Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !'] = df['Perhatikan gambar berikut. Jelaskan secara rinci kondisi berdasarkan gambar di bawah ini !'].apply(remove_whitespace_LT)
# df.head(n=10)

# %%
# for produto in df.iterrows():
#     if (produto[0] == 1):
#         lowercase_sentence = produto[1][0]

# %%
import string
import nltk
nltk.download('punkt')
import re #regex library

# import word_tokenize from NLTK
from nltk.tokenize import word_tokenize 



# ------ Case Folding --------
# gunakan fungsi .lower()
lowercase_sentence = sentence.lower()

print('Case Folding Result : \n')
print(lowercase_sentence)
print('\n\n\n')

# ------ Tokenizing ---------
#remove angka
lowercase_sentence = re.sub(r"\d+", "", lowercase_sentence)

#remove punctuation
lowercase_sentence = lowercase_sentence.translate(str.maketrans("","",string.punctuation))

#remove whitespace leading & trailing
lowercase_sentence = lowercase_sentence.strip()

#remove multiple whitespace into single whitespace
lowercase_sentence = re.sub('\s+',' ',lowercase_sentence)


tokens = nltk.tokenize.word_tokenize(lowercase_sentence)

print('Tokenizing Result : \n') 
print(tokens)
freq_tokens = nltk.FreqDist(tokens)

print('Frequency Tokens : \n') 
print(freq_tokens.most_common())
# Out:
# Case Folding Result :
#
# dari gambar tersebut saya melihat kemacetan lalu lintas yang sangat parah, kemacetan terjadi karena banyaknya kendaraan roda dua dan roda empat. selain itu, sebab utama dari kemacetan lalu lintas adalah tingginya tingkat kepadatan penduduk.
#
#
#
#
# Tokenizing Result :
#
# ['dari', 'gambar', 'tersebut', 'saya', 'melihat', 'kemacetan', 'lalu', 'lintas', 'yang', 'sangat', 'parah', 'kemacetan', 'terjadi', 'karena', 'banyaknya', 'kendaraan', 'roda', 'dua', 'dan', 'roda', 'empat', 'selain', 'itu', 'sebab', 'utama', 'dari', 'kemacetan', 'lalu', 'lintas', 'adalah', 'tingginya', 'tingkat', 'kepadatan', 'penduduk']
# Frequency Tokens :
#
# [('kemacetan', 3), ('dari', 2), ('lalu', 2), ('lintas', 2), ('roda', 2), ('gambar', 1), ('tersebut', 1), ('saya', 1), ('melihat', 1), ('yang', 1), ('sangat', 1), ('parah', 1), ('terjadi', 1), ('karena', 1), ('banyaknya', 1), ('kendaraan', 1), ('dua', 1), ('dan', 1), ('empat', 1), ('selain', 1), ('itu', 1), ('sebab', 1), ('utama', 1), ('adalah', 1), ('tingginya', 1), ('tingkat', 1), ('kepadatan', 1), ('penduduk', 1)]
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ifarm\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_freq_tokens = pd.DataFrame.from_dict(freq_tokens, orient='index')
df_freq_tokens.columns = ['Frequency'] 
df_freq_tokens.index.name = 'Key'

df_freq_tokens.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Key'>

# %%
df_freq_tokens.sort_values('Frequency')
# Out:
#            Frequency
# Key
# banyaknya          1
# tingkat            1
# tingginya          1
# adalah             1
# utama              1
# sebab              1
# itu                1
# selain             1
# empat              1
# dan                1
# dua                1
# kendaraan          1
# kepadatan          1
# penduduk           1
# terjadi            1
# parah              1
# sangat             1
# yang               1
# melihat            1
# saya               1
# tersebut           1
# gambar             1
# karena             1
# roda               2
# lintas             2
# lalu               2
# dari               2
# kemacetan          3

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ifarm\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# tokenize text
freq_tokens

# get Indonesian stopword 
list_stopwords = set(stopwords.words('indonesian'))

#remove stopword pada list token
tokens_without_stopword = [word for word in freq_tokens if not word in list_stopwords]


print(tokens_without_stopword)
# Out:
# ['kemacetan', 'lintas', 'roda', 'gambar', 'parah', 'banyaknya', 'kendaraan', 'utama', 'tingginya', 'tingkat', 'kepadatan', 'penduduk']

# %%
pip install sastrawi
# Out:
# Requirement already satisfied: sastrawi in c:\users\ifarm\appdata\local\programs\python\python39\lib\site-packages (1.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# token without stopword
list_tokens = tokens_without_stopword

# stem
output   = [(token + " : " + stemmer.stem(token)) for token in list_tokens]

output
# Out:
# ['kemacetan : macet',
#  'lintas : lintas',
#  'roda : roda',
#  'gambar : gambar',
#  'parah : parah',
#  'banyaknya : banyak',
#  'kendaraan : kendara',
#  'utama : utama',
#  'tingginya : tinggi',
#  'tingkat : tingkat',
#  'kepadatan : padat',
#  'penduduk : duduk']
